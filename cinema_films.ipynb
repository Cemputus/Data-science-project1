# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinema = pd.read_csv('data/cinema_films.csv')
cinema
# Out:
#    id                                             title  release_year  \
# 0   1  Intolerance: Love's Struggle Throughout the Ages          1916
# 1   2                    Over the Hill to the Poorhouse          1920
# 2   3                                    The Big Parade          1925
# 3   4                                        Metropolis          1927
# 4   5                                     Pandora's Box          1929
# 5   6                               The Broadway Melody          1929
# 6   7                                     Hell's Angels          1930
# 7   8                                A Farewell to Arms          1932
# 8   9                                       42nd Street          1933
# 9  10                                She Done Him Wrong          1933
#
#    country  duration language certification      gross     budget
# 0      USA       123      NaN     Not Rated        NaN   385907.0
# ...
